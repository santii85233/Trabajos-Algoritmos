# %% [markdown]
# # Reto 1 C++

# %% [markdown]
# ### Diagrama de Flujo

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./abuelita.jpg" width="auto"/></td>
# </table>

# %% [markdown]
# ### Codigo C++

# %% [markdown]
# #include <iostream>
#
# using namespace std;
#
# int main(){
#
#     int temperaturaF, temperaturaC, cambio; //Definir variables
#     cout<<"Ingrese su temperatura en °Fahrenheit:";
#     cin>>temperaturaF; //Leer temperatura
#     temperaturaC = (temperaturaF-32)/1.8; //Conversion de unidades
#     cout<<"Su temperatura en grados Celsius es de:"<<temperaturaC<<endl; //Mostrar el resultado
#     return 0;
#
# }
